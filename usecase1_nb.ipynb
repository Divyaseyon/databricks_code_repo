# %% [markdown]
# #Inceptez WE47 Cloud AI Engineer

# %% [markdown]
# ##We are the **Bigdata** multi cloud based AI data engineers where we learn about datawarehousing, pyspark, cloud and AI.

# %% [markdown]
# ###*$${\color{red}Divya Bharathy}$$*

# %% [markdown]
# ![](https://fpimages.withfloats.com/actual/6936e213e40c3ddda3969dd0.jpeg)

# %%
# %sql
create volume if not exists workspace.default.usage_metrics

# %%
# %run "/Workspace/Users/divsept@gmail.com/4_child_nb_dataload"

# %%
# %fs
ls /Volumes/workspace/default/usage_metrics/mobile_os_usage.csv

# %%
# %fs head /Volumes/workspace/default/usage_metrics/mobile_os_usage.csv

# %%
df1 = spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",header = 'True', inferSchema='True')
df1.write.saveAsTable("mobile_os_usage_final")

# %%
# %sql

select * from workspace.default.mobile_os_usage limit 10

# %%
# %python
df = spark.read.table("workspace.default.mobile_os_usage")
df1 = df.createOrReplaceTempView("refdata")
df2 = spark.sql("select * from refdata")
df2.show(10)

# %%
df = spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",header='True').toDF("date","os","usage")
df.write.saveAsTable("mobile_os_usage_final")

# %%
# %sql
select * from mobile_os_usage_final limit 10

# %%
def upper(a):
    return a.upper()

# %%
print("upper case of input ",upper('divya'))

# %%
# %pip install pandas

# %%
import pandas as pd
df_pd = pd.read_csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
print(df_pd.head())

# %%
# %sh
echo "Magic commands tasks completed"
