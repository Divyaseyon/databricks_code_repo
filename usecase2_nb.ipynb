# %%
# %sql
create volume if not exists workspace.default.volumewe47_datalake

# %%
base_path = "/Volumes/workspace/default/volumewe47_datalake"
raw_path = f"{base_path}/raw"
processed_path = f"{base_path}/processed"
archive_path = f"{base_path}/archive"

# %%
dbutils.fs.mkdirs("dbfs:/Volumes/workspace/default/volumewe47_datalake/raw")

# %%
dbutils.fs.mkdirs("dbfs:/Volumes/workspace/default/volumewe47_datalake/processed")

# %%
dbutils.fs.mkdirs("dbfs:/Volumes/workspace/default/volumewe47_datalake/archive")

# %%
sample_data = """patient_id,patient_name,age,gender 1,John Doe,68,M 2,Jane Smith,54,F """

# %%
dbutils.fs.put("dbfs:/Volumes/workspace/default/volumewe47_datalake/raw/sample.txt",sample_data,True)

# %%
dbutils.fs.ls("dbfs:/Volumes/workspace/default/volumewe47_datalake/raw/")

# %%
dbutils.fs.cp("dbfs:/Volumes/workspace/default/volumewe47_datalake/raw/sample.txt","dbfs:/Volumes/workspace/default/volumewe47_datalake/processed/")

# %%
dbutils.widgets.dropdown("environment","dev",["dev","qa","prod"])
dbutils.widgets.text("owner_name","Divya","enter the owner name")
env=dbutils.widgets.get("environment")
owner=dbutils.widgets.get("owner_name")
print(f"The Environment is {env} and the owner name is {owner}")

# %%
dbutils.fs.mv("dbfs:/Volumes/workspace/default/volumewe47_datalake/processed/sample.txt","dbfs:/Volumes/workspace/default/volumewe47_datalake/archive/")

# %%
return_status=dbutils.notebook.run("/Workspace/Users/divsept@gmail.com/4_child_nb_dataload",90)

# %%
dbutils.notebook.exit("Pipeline completed successfully")
